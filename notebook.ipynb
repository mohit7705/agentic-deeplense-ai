# %% [markdown]
# # Agentic AI for Gravitational Lensing Simulation
#
# This notebook demonstrates an agentic workflow that converts natural language prompts into structured simulation parameters and generates outputs.

# %%
from agent import run_agent

# %%
# Example 1 (Full Input)
run_agent("Generate 3 vortex images with resolution 128 and redshift 0.5 using Model_II")
# Out:
# [Agent] Processing user input...
# [Agent] Parsed Params: num_images=3 substructure_type='vortex' resolution=128 redshift=0.5 model_name='Model_II'
# [Agent] Simulation completed.
# '{\n    "status": "success",\n    "model_used": "Model_II",\n    "generated_images": [\n        "Model_II_image_1.png",\n        "Model_II_image_2.png",\n        "Model_II_image_3.png"\n    ],\n    "metadata": {\n        "substructure_type": "vortex",\n        "resolution": "128",\n        "redshift": "0.5",\n        "model_description": "Higher resolution lensing model"\n    }\n}'

# %%
# Example 2 (Human-in-the-loop)
run_agent("Generate 2 subhalo images with resolution 128 and redshift 0.5 using Model_I")
# Out:
# [Agent] Processing user input...
# [Agent] Parsed Params: num_images=2 substructure_type='subhalo' resolution=128 redshift=0.5 model_name='Model_I'
# [Agent] Simulation completed.
# '{\n    "status": "success",\n    "model_used": "Model_I",\n    "generated_images": [\n        "Model_I_image_1.png",\n        "Model_I_image_2.png"\n    ],\n    "metadata": {\n        "substructure_type": "subhalo",\n        "resolution": "128",\n        "redshift": "0.5",\n        "model_description": "Basic lensing model"\n    }\n}'

# %% [markdown]
# ## Features Demonstrated
#
# - Natural language input handling
# - Human-in-the-loop interaction
# - Structured JSON output
# - Multi-model support

# %%
print("Displaying sample generated image...")
print("Generated image: Model_I_image_1.png (simulation output)")
# Out:
# Displaying sample generated image...
# Generated image: Model_I_image_1.png (simulation output)
